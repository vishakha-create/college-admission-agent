# %%
# Out:
# Getting access token...
# Error getting access token: 400 Client Error: Bad Request for url: https://iam.cloud.ibm.com/identity/token
# Failed to get access token. Exiting.

# %%
import requests

# STEP 1: Authentication using your IBM Cloud API Key
API_KEY = "cpd-apikey-IBMid-6950010BR4-2025-07-29T14:09:03Z"
token_response = requests.post(
    'https://iam.cloud.ibm.com/identity/token',
    data={"apikey": API_KEY, "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'}
)
mltoken = token_response.json()["access_token"]

# STEP 2: Set the header with the token
header = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + mltoken
}

# STEP 3: Set your user message here
payload_scoring = {
    "messages": [
        {"content": "Tell me about the admission process", "role": "user"}
    ]
}

# STEP 4: Replace this with your actual deployment URL
deployment_url = "https://us-south.ml.cloud.ibm.com/ml/v4/deployments/eb2e323e-893f-4452-82d8-3ed9ac19663d/ai_service_stream?version=2021-05-01"

# STEP 5: Send the request
response_scoring = requests.post(deployment_url, json=payload_scoring, headers=header)

# STEP 6: Display the response
print("Scoring response:")
try:
    print(response_scoring.json())
except ValueError:
    print(response_scoring.text)
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 9
#       4 API_KEY = "cpd-apikey-IBMid-6950010BR4-2025-07-29T14:09:03Z"
#       5 token_response = requests.post(
#       6     'https://iam.cloud.ibm.com/identity/token',
#       7     data={"apikey": API_KEY, "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'}
#       8 )
# ----> 9 mltoken = token_response.json()["access_token"]
#      11 # STEP 2: Set the header with the token
#      12 header = {
#      13     'Content-Type': 'application/json',
#      14     'Authorization': 'Bearer ' + mltoken
#      15 }
#
# KeyError: 'access_token'

# %%
import requests

# ✅ IBM Cloud API Key (use the actual one, not the display label)
API_KEY = "ApiKey-7d5755e2-3fc6-4bb7-bec4-f82a8d7e04b5"

# STEP 1: Get access token using the API key
token_response = requests.post(
    'https://iam.cloud.ibm.com/identity/token',
    data={
        "apikey": API_KEY,
        "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'
    }
)

# DEBUG: Check token response
print("Status Code:", token_response.status_code)
print("Raw Token Response:", token_response.text)

# STEP 2: Extract access token from response
try:
    mltoken = token_response.json()["access_token"]
except KeyError:
    print("❌ Failed to extract access_token. Please check if API key is valid.")
    exit()

# STEP 3: Prepare header with the access token
header = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + mltoken
}

# STEP 4: Prepare payload (update user message as needed)
payload_scoring = {
    "messages": [
        {
            "content": "Tell me about hostel fees and deadlines",
            "role": "user"
        }
    ]
}

# STEP 5: Make POST request to your deployed model (replace with your real deployment URL)
response_scoring = requests.post(
    'https://us-south.ml.cloud.ibm.com/ml/v4/deployments/eb2e323e-893f-4452-82d8-3ed9ac19663d/ai_service_stream?version=2021-05-01',
    json=payload_scoring,
    headers=header
)

# STEP 6: Display the scoring response
print("Scoring response:")
try:
    print(response_scoring.json())
except ValueError:
    print(response_scoring.text)
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Status Code: 400
# Raw Token Response: {"errorCode":"BXNIM0415E","errorMessage":"Provided API key could not be found.","context":{"requestId":"NGptcW0-6fc22f5833d74ddea8765fea9294ae80","requestType":"incoming.Identity_Token","userAgent":"python-requests/2.32.4","url":"https://iam.cloud.ibm.com","instanceId":"iamid-10-6-5031-9dbf5b6-65f7489597-4jmqm","threadId":"20c292","host":"iamid-10-6-5031-9dbf5b6-65f7489597-4jmqm","startTime":"29.07.2025 16:20:41:170 UTC","endTime":"29.07.2025 16:20:41:237 UTC","elapsedTime":"67","locale":"en_US","clusterName":"iam-id-prod-us-south-dal10"}}
# ❌ Failed to extract access_token. Please check if API key is valid.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 29
#      24     exit()
#      26 # STEP 3: Prepare header with the access token
#      27 header = {
#      28     'Content-Type': 'application/json',
# ...

# %%
import requests

# ✅ Insert your actual IBM Cloud API key here
API_KEY = "ApiKey-7d5755e2-3fc6-4bb7-bec4-f82a8d7e04b5"

# Get the IAM token
token_response = requests.post(
    'https://iam.cloud.ibm.com/identity/token',
    data={"apikey": API_KEY, "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'}
)

# Extract the token
mltoken = token_response.json()["access_token"]

# Header with bearer token
header = {'Content-Type': 'application/json', 'Authorization': 'Bearer ' + mltoken}

# Example user message
payload_scoring = {
    "messages": [
        {
            "content": "Tell me about hostel fees and deadlines",
            "role": "user"
        }
    ]
}

# POST to the deployed AI service (update this URL if needed)
response_scoring = requests.post(
    'https://us-south.ml.cloud.ibm.com/ml/v4/deployments/eb2e323e-893f-4452-82d8-3ed9ac19663d/ai_service_stream?version=2021-05-01',
    json=payload_scoring,
    headers={'Authorization': 'Bearer ' + mltoken}
)

# Print the result
print("Scoring response")
try:
    print(response_scoring.json())
except ValueError:
    print(response_scoring.text)
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 13
#       7 token_response = requests.post(
#       8     'https://iam.cloud.ibm.com/identity/token',
#       9     data={"apikey": API_KEY, "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'}
#      10 )
#      12 # Extract the token
# ---> 13 mltoken = token_response.json()["access_token"]
#      15 # Header with bearer token
#      16 header = {'Content-Type': 'application/json', 'Authorization': 'Bearer ' + mltoken}
#
# KeyError: 'access_token'

# %%
import requests

# ✅ Your valid IBM Cloud API Key
API_KEY = "ApiKey-7d5755e2-3fc6-4bb7-bec4-f82a8d7e04b5"

# STEP 1: Request IAM access token
token_response = requests.post(
    'https://iam.cloud.ibm.com/identity/token',
    data={"apikey": API_KEY, "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'}
)

# Print response to debug
print("Status Code:", token_response.status_code)
print("Token Response:", token_response.text)

# STEP 2: Check if access_token is present
if token_response.status_code == 200:
    try:
        mltoken = token_response.json()["access_token"]
        print("✅ Token retrieved.")
    except KeyError:
        print("❌ access_token not found in response.")
        exit()
else:
    print("❌ Failed to retrieve token. Check your API key.")
    exit()

# STEP 3: Set the header with token
header = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + mltoken
}

# STEP 4: Set payload for testing
payload_scoring = {
    "messages": [
        {
            "content": "Tell me about hostel fees and deadlines",
            "role": "user"
        }
    ]
}

# STEP 5: Replace with your actual deployed model endpoint
response_scoring = requests.post(
    'https://us-south.ml.cloud.ibm.com/ml/v4/deployments/eb2e323e-893f-4452-82d8-3ed9ac19663d/ai_service_stream?version=2021-05-01',
    json=payload_scoring,
    headers=header
)

# STEP 6: Print response
print("Scoring Response:")
try:
    print(response_scoring.json())
except Exception as e:
    print("❌ Error decoding response:", str(e))
    print(response_scoring.text)
# Out:
# Status Code: 400
# Token Response: {"errorCode":"BXNIM0415E","errorMessage":"Provided API key could not be found.","context":{"requestId":"NWt3bjI-c6ba6343bf8641cdbfe7c1c4664aeb46","requestType":"incoming.Identity_Token","userAgent":"python-requests/2.32.4","url":"https://iam.cloud.ibm.com","instanceId":"iamid-10-6-5031-9dbf5b6-65f7489597-5kwn2","threadId":"1dda82","host":"iamid-10-6-5031-9dbf5b6-65f7489597-5kwn2","startTime":"29.07.2025 16:21:56:547 UTC","endTime":"29.07.2025 16:21:56:616 UTC","elapsedTime":"69","locale":"en_US","clusterName":"iam-id-prod-us-south-dal12"}}
# ❌ Failed to retrieve token. Check your API key.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 31
#      26     exit()
#      28 # STEP 3: Set the header with token
#      29 header = {
#      30     'Content-Type': 'application/json',
# ---> 31     'Authorization': 'Bearer ' + mltoken
# ...

# %%
import requests

# ✅ Use the actual API key (not display label)
API_KEY = "ApiKey-7d5755e2-3fc6-4bb7-bec4-f82a8d7e04b5"

# STEP 1: Request IAM token
token_response = requests.post(
    'https://iam.cloud.ibm.com/identity/token',
    data={
        "apikey": API_KEY,
        "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'
    }
)

# STEP 2: Print raw token response for debugging
print("🔍 Token Request Status Code:", token_response.status_code)
print("🔍 Token Response Body:", token_response.text)

# STEP 3: Extract access token only if response is successful
if token_response.status_code == 200:
    try:
        mltoken = token_response.json()["access_token"]
        print("✅ Access token successfully retrieved.")
    except KeyError:
        print("❌ 'access_token' not found in response.")
        exit()
else:
    print("❌ Failed to retrieve token. Please verify API key and permissions.")
    exit()

# STEP 4: Set the authorization header
header = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + mltoken
}

# STEP 5: Sample user message payload (customize as needed)
payload_scoring = {
    "messages": [
        {
            "content": "Tell me about hostel fees and deadlines",
            "role": "user"
        }
    ]
}

# STEP 6: POST request to deployed model endpoint (replace with your deployment URL if different)
response_scoring = requests.post(
    'https://us-south.ml.cloud.ibm.com/ml/v4/deployments/eb2e323e-893f-4452-82d8-3ed9ac19663d/ai_service_stream?version=2021-05-01',
    json=payload_scoring,
    headers=header
)

# STEP 7: Print scoring response
print("🤖 Scoring Response:")
try:
    print(response_scoring.json())
except Exception as e:
    print("❌ Failed to parse response:", str(e))
    print(response_scoring.text)
# Out:
# 🔍 Token Request Status Code: 400
# 🔍 Token Response Body: {"errorCode":"BXNIM0415E","errorMessage":"Provided API key could not be found.","context":{"requestId":"a3R0bjQ-015de34dc1764239a670c828a63623fa","requestType":"incoming.Identity_Token","userAgent":"python-requests/2.32.4","url":"https://iam.cloud.ibm.com","instanceId":"iamid-10-6-5031-9dbf5b6-65f7489597-kttn4","threadId":"1dc1f7","host":"iamid-10-6-5031-9dbf5b6-65f7489597-kttn4","startTime":"29.07.2025 16:28:48:109 UTC","endTime":"29.07.2025 16:28:48:194 UTC","elapsedTime":"85","locale":"en_US","clusterName":"iam-id-prod-us-south-dal12"}}
# ❌ Failed to retrieve token. Please verify API key and permissions.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 34
#      29     exit()
#      31 # STEP 4: Set the authorization header
#      32 header = {
#      33     'Content-Type': 'application/json',
# ...

# %%
import requests

#  Use the actual API key (NOT the label)
API_KEY = "ApiKey-7d5755e2-3fc6-4bb7-bec4-f82a8d7e04b5"

# STEP 1: Get IAM token
token_response = requests.post(
    'https://iam.cloud.ibm.com/identity/token',
    data={"apikey": API_KEY, "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'}
)

# DEBUG: Print token response
print(" Status Code:", token_response.status_code)
print(" Token Response:", token_response.text)

# STEP 2: Extract access_token
if token_response.status_code == 200:
    try:
        mltoken = token_response.json()["access_token"]
        print(" Token retrieved successfully.")
    except KeyError:
        print(" 'access_token' not found in the response. Please check API key.")
        exit()
else:
    print(" Failed to get token. Check API key and IAM permissions.")
    exit()

# STEP 3: Set header with token
header = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + mltoken
}

# STEP 4: Define payload (customize this for your chatbot)
payload_scoring = {
    "messages": [
        {
            "content": "What are the hostel fees and amenities?",
            "role": "user"
        }
    ]
}

# STEP 5: Send request to deployed Watson model
response_scoring = requests.post(
    'https://us-south.ml.cloud.ibm.com/ml/v4/deployments/4a252c20-5dd2-4b99-8086-bff061a094cf/ai_service_stream?version=2021-05-01',
    json=payload_scoring,
    headers=header
)

# STEP 6: Show the chatbot's response
print(" Scoring response:")
try:
    print(response_scoring.json())
except ValueError:
    print(" Could not decode response as JSON.")
    print(response_scoring.text)
except Exception as e:
    print(f" Unexpected error: {e}")
# Out:
#  Status Code: 400
#  Token Response: {"errorCode":"BXNIM0415E","errorMessage":"Provided API key could not be found.","context":{"requestId":"aGtjeG4-d1732d3574774d1c9f107ee5a8fe3d80","requestType":"incoming.Identity_Token","userAgent":"python-requests/2.32.4","url":"https://iam.cloud.ibm.com","instanceId":"iamid-10-6-5031-9dbf5b6-65f7489597-hkcxn","threadId":"1e8e79","host":"iamid-10-6-5031-9dbf5b6-65f7489597-hkcxn","startTime":"29.07.2025 16:31:49:903 UTC","endTime":"29.07.2025 16:31:49:978 UTC","elapsedTime":"75","locale":"en_US","clusterName":"iam-id-prod-us-south-dal12"}}
#  Failed to get token. Check API key and IAM permissions.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 31
#      26     exit()
#      28 # STEP 3: Set header with token
#      29 header = {
#      30     'Content-Type': 'application/json',
# ...

# %%
import requests

API_KEY = "ApiKey-7d5755e2-3fc6-4bb7-bec4-f82a8d7e04b5"

# STEP 1: Get IAM token
token_response = requests.post(
    'https://iam.cloud.ibm.com/identity/token',
    data={"apikey": API_KEY, "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'}
)

# Print raw token response (for debugging)
print("Status:", token_response.status_code)
print("Token response:", token_response.text)

# STEP 2: Check and extract token safely
if token_response.status_code == 200:
    json_response = token_response.json()
    if "access_token" in json_response:
        mltoken = json_response["access_token"]
        print("✅ Access token retrieved.")
    else:
        print("❌ 'access_token' missing in response.")
        exit()
else:
    print("❌ Token request failed. Check your API key.")
    exit()

# STEP 3: Now we can safely use mltoken
header = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + mltoken
}

# From here, your scoring logic continues...
# Out:
# Status: 400
# Token response: {"errorCode":"BXNIM0415E","errorMessage":"Provided API key could not be found.","context":{"requestId":"cHZqYzQ-cf6390bbb2a44c1085c6cc24f88fa811","requestType":"incoming.Identity_Token","userAgent":"python-requests/2.32.4","url":"https://iam.cloud.ibm.com","instanceId":"iamid-10-6-5031-9dbf5b6-65f7489597-pvjc4","threadId":"1dca15","host":"iamid-10-6-5031-9dbf5b6-65f7489597-pvjc4","startTime":"29.07.2025 16:33:31:765 UTC","endTime":"29.07.2025 16:33:31:836 UTC","elapsedTime":"71","locale":"en_US","clusterName":"iam-id-prod-us-south-dal12"}}
# ❌ Token request failed. Check your API key.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 31
#      26     exit()
#      28 # STEP 3: Now we can safely use mltoken
#      29 header = {
#      30     'Content-Type': 'application/json',
# ---> 31     'Authorization': 'Bearer ' + mltoken
# ...
